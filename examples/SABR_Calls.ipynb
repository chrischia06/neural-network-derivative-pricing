# %% [markdown]
# # Prediction - European Calls

# %%
# %run key_imports.py
# %run sabr.py
# %run nn_archi.py
# %run utils.py

X_df = pd.read_csv("datasets/sabr.csv")
feat_names = ["S/K", "ttm", "V", "vol_of_vol", "beta", "rho"]
f_to_i = lambda x: feat_names.index(x)
Xs = X_df[feat_names].values
ys = X_df["call_payoff"]

print("BASELINE MSE: ", np.mean((ys - ys.mean()) ** 2))
print("BASELINE MAE: ", np.mean(np.abs(ys - ys.mean())))

all_res = []
# Out:
# BASELINE MSE:  0.043798371266515146
# BASELINE MAE:  0.14524983403682704

# %%
HIDDEN_UNITS = 100
LAYERS = 2
dropout_ratio = 0.0
HIDDEN_ACT = "softplus"
N_FEATS = Xs.shape[1]
OUTPUT_ACT = None
DROPOUT_RATIO = 0.0
LR = 1e-3
BATCH_SIZE = 32
EPOCHS = 30
BATCH_NORM = False

"""
Unconstrained NN
"""
loss_fn = tf.keras.losses.MeanSquaredError()

METRICS = [
    tf.keras.metrics.MeanAbsoluteError(),
    tf.keras.metrics.RootMeanSquaredError(),
]
VAL_SPLIT = 0.2
CALLBACKS = [EarlyStopping(patience=5)]


opt = Adam(learning_rate=LR)
ffn = make_model(
    N_FEATS, HIDDEN_UNITS, LAYERS, DROPOUT_RATIO, HIDDEN_ACT, OUTPUT_ACT, BATCH_NORM
)


ffn.compile(optimizer=opt, loss=loss_fn, metrics=METRICS)
start = time.time()
history = ffn.fit(
    Xs,
    ys,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=VAL_SPLIT,
    shuffle=False,
    verbose=1,
    callbacks=CALLBACKS,
)
end = time.time()

metrics = ["mean_absolute_error", "root_mean_squared_error"]
fig, ax = plt.subplots(figsize=(15, 5), ncols=2)
for i, metric in enumerate(metrics):
    ax[i].plot(history.history[metric], label="train")
    ax[i].plot(history.history[f"val_{metric}"], label="val")
    ax[i].legend()
    ax[i].set_title(metric)
# Out:
# Epoch 1/30
# 253/253 [==============================] - 1s 2ms/step - loss: 0.0789 - mean_absolute_error: 0.2136 - root_mean_squared_error: 0.2809 - val_loss: 0.2159 - val_mean_absolute_error: 0.3356 - val_root_mean_squared_error: 0.4647
# Epoch 2/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0759 - mean_absolute_error: 0.2167 - root_mean_squared_error: 0.2755 - val_loss: 0.2557 - val_mean_absolute_error: 0.3937 - val_root_mean_squared_error: 0.5057
# Epoch 3/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0585 - mean_absolute_error: 0.1911 - root_mean_squared_error: 0.2418 - val_loss: 0.1363 - val_mean_absolute_error: 0.1941 - val_root_mean_squared_error: 0.3692
# Epoch 4/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0512 - mean_absolute_error: 0.1752 - root_mean_squared_error: 0.2263 - val_loss: 0.1171 - val_mean_absolute_error: 0.1696 - val_root_mean_squared_error: 0.3421
# Epoch 5/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0467 - mean_absolute_error: 0.1663 - root_mean_squared_error: 0.2161 - val_loss: 0.1164 - val_mean_absolute_error: 0.1681 - val_root_mean_squared_error: 0.3412
# Epoch 6/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0429 - mean_absolute_error: 0.1561 - root_mean_squared_error: 0.2071 - val_loss: 0.1200 - val_mean_absolute_error: 0.1668 - val_root_mean_squared_error: 0.3464
# Epoch 7/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0394 - mean_absolute_error: 0.1475 - root_mean_squared_error: 0.1986 - val_loss: 0.1232 - val_mean_absolute_error: 0.1706 - val_root_mean_squared_error: 0.3511
# Epoch 8/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0368 - mean_absolute_error: 0.1407 - root_mean_squared_error: 0.1917 - val_loss: 0.1260 - val_mean_absolute_error: 0.1767 - val_root_mean_squared_error: 0.3550
# Epoch 9/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0348 - mean_absolute_error: 0.1356 - root_mean_squared_error: 0.1866 - val_loss: 0.1262 - val_mean_absolute_error: 0.1770 - val_root_mean_squared_error: 0.3553
# Epoch 10/30
# 253/253 [==============================] - 0s 2ms/step - loss: 0.0334 - mean_absolute_error: 0.1328 - root_mean_squared_error: 0.1828 - val_loss: 0.1236 - val_mean_absolute_error: 0.1708 - val_root_mean_squared_error: 0.3515

# %%
"""
Prediction Errors
"""
model = ffn
moneyness = Xs[:, f_to_i("S/K")]
ttm = Xs[:, f_to_i("ttm")]
true = X_df["call_payoff"]
intrinsic_val = np.maximum(moneyness - 1.0, 0)
preds = model.predict(Xs)
try:
    preds = preds.reshape(-1)
except:
    pass

"""
Compute all Gradients, Hessian
"""

X_tensor = tf.Variable(Xs)
with tf.GradientTape() as tape2:
    with tf.GradientTape() as tape:
        output = model(X_tensor)
        grads = tape.gradient(output, X_tensor)
    hessian1 = tape2.gradient(grads[:, f_to_i("S/K")], X_tensor)

grads = grads.numpy()
hessian_moneyness = hessian1.numpy()[:, [0]]

# all_res += [bs_eval_wrapper(X_df,
#                     true_val = X_df['call_true'].values,
#                     preds = preds,
#                     grads = grads,
#                     hessian_moneyness = hessian_moneyness,
#                     lower_bound = intrinsic_val,
#                     upper_bound = None,
#                     METHOD = "standard_ffn"
#                     )]

"""
Visualise call surface
"""
N_POINTS = 128
SK = np.linspace(0.0, 3, N_POINTS)
ts = np.linspace(0, 4.0, N_POINTS)
X = np.zeros((N_POINTS**2, N_FEATS))
X[:, :2] = np.array(list(product(SK, ts)))
X[:, f_to_i("V")] = 0.2
X[:, f_to_i("vol_of_vol")] = 0.1
X[:, f_to_i("rho")] = 0.3
X[:, f_to_i("beta")] = 1.0

temp = visualise_surface(SK, ts, model(X).numpy())
type(temp)
# Out:
# matplotlib.axes._subplots.Axes3DSubplot

# %% [markdown]
# # NN with a homogeneity hint

# %%
CALLBACKS = [EarlyStopping(patience=5)]
opt = Adam(learning_rate=1e-1)

intrinsic_value = np.maximum(np.exp(Xs[:, 0]) - 1.0, 0)
gated_model = homogeneity_network(2, 100, seed=42)
gated_model.compile(optimizer=opt, loss=loss_fn, metrics=METRICS)
start = time.time()
history = gated_model.fit(
    [Xs[:, 0], Xs[:, 1]],
    ys,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=VAL_SPLIT,
    verbose=0,
    shuffle=True,
    callbacks=CALLBACKS,
)
end = time.time()
print(end - start)
# Out:
# 3.725986957550049

# %%
preds = (gated_model.predict([Xs[:, 0], Xs[:, 1]]).reshape(-1)).reshape(-1)

"""
Compute all Gradients, Hessian
"""

X_tensor = tf.Variable(Xs)
with tf.GradientTape() as tape2:
    with tf.GradientTape() as tape:
        output = gated_model([X_tensor[:, 0], X_tensor[:, 1]])
        grads = tape.gradient(output, X_tensor)
    hessian1 = tape2.gradient(grads[:, f_to_i("S/K")], X_tensor)

grads = grads.numpy()
hessian_moneyness = hessian1.numpy()[:, [0]]

all_res += [
    bs_eval_wrapper(
        X_df,
        true_val=X_df["call_true"].values,
        preds=preds,
        grads=grads,
        hessian_moneyness=hessian_moneyness,
        lower_bound=intrinsic_val,
        upper_bound=None,
        METHOD="homogeneity_network",
    )
]

"""
Visualise call surface
"""
SK = np.linspace(-2, 3, 128)
ts = np.linspace(0, 4, 128)
X = np.array(list(product(SK, ts)))
visualise_surface(SK, ts, gated_model([X[:, 0], X[:, 1]]).numpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gg/bdgg0c0n28x14l2hd83rbx3c0000gn/T/ipykernel_5956/3241124700.py in <module>
#      15 hessian_moneyness = hessian1.numpy()[:, [0]]
#      16
# ---> 17 all_res += [bs_eval_wrapper(X_df,
#      18                     true_val = X_df['call_true'].values,
#      19                     preds = preds,
#
# NameError: name 'bs_eval_wrapper' is not defined

# %% [markdown]
# # Polynomial Basis

# %%
from sklearn.preprocessing import PolynomialFeatures, SplineTransformer
from sklearn.linear_model import LinearRegression, LogisticRegression

X2 = SplineTransformer(
    n_knots=5, degree=3, knots="uniform", extrapolation="constant"
).fit_transform(Xs)

reg = LinearRegression(fit_intercept=False).fit(X2, X_df["call_payoff"])
sns.scatterplot(x=Xs[:, f_to_i("S/K")], y=reg.predict(X2), hue=Xs[:, f_to_i("ttm")])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Neural PDE

# %%
dataset = tf.data.Dataset.from_tensor_slices((Xs, ys))

# %%
opt = Adam(learning_rate=LR)
model = make_model(
    N_FEATS, HIDDEN_UNITS, LAYERS, DROPOUT_RATIO, HIDDEN_ACT, OUTPUT_ACT, BATCH_NORM
)

batched_dataset = dataset.batch(BATCH_SIZE)


@tf.function
def train(y, x_var):
    with tf.GradientTape() as model_tape:
        with tf.GradientTape() as hessian_tape:
            with tf.GradientTape() as grad_tape:
                output = model(x_var)
            # gradients = grad_tape.gradient(output, x_var)
            # hessian = hessian_tape.gradient(gradients[:,0], x_var)
            # pde_loss = tf.math.reduce_mean((gradients[:,1] + x_var[:,1] * (-hessian[:,0] + gradients[:,0])) ** 2)
            pde_loss = 0.0
            pred_loss = tf.keras.losses.MeanSquaredError()(output, y)
            loss = pred_loss  # pde_loss + pred_loss
            model_grad = model_tape.gradient(loss, model.trainable_variables)
            opt.apply_gradients(zip(model_grad, model.trainable_variables))
    return loss, pred_loss, pde_loss


losses = {"pde": [], "loss": [], "pred": []}
for epoch in tqdm(range(EPOCHS)):
    temp_pred = []
    temp_pde = []
    temp_loss = []
    for step, (x, y_true) in enumerate(batched_dataset):
        x_var = tf.Variable(x)
        loss, pred_loss, pde_loss = train(y_true, x_var)
        temp_pred += [pred_loss.numpy()]
        # temp_pde += [pde_loss.numpy()]
        temp_loss += [loss.numpy()]
    # losses['pde'] += [np.mean(temp_pde)]
    losses["pred"] += [np.mean(temp_pred)]
    losses["loss"] += [np.mean(temp_loss)]
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
preds = model.predict(Xs).reshape(-1)
"""
Compute all Gradients, Hessian
"""

X_tensor = tf.Variable(Xs)
with tf.GradientTape() as tape2:
    with tf.GradientTape() as tape:
        output = model(X_tensor)
        grads = tape.gradient(output, X_tensor)
    hessian1 = tape2.gradient(grads[:, f_to_i("log(S/K)")], X_tensor)

grads = grads.numpy()
hessian_moneyness = hessian1.numpy()[:, [0]]

all_res += [
    bs_eval_wrapper(
        X_df,
        true_val=X_df["call_true"].values,
        preds=preds,
        grads=grads,
        hessian_moneyness=hessian_moneyness,
        lower_bound=intrinsic_val,
        upper_bound=None,
        METHOD="ffn+neural_pde",
    )
]

"""
Visualise call surface
"""
SK = np.linspace(-2, 3, 128)
ts = np.linspace(0, 4, 128)
X = np.array(list(product(SK, ts)))
visualise_surface(SK, ts, model(X).numpy())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gg/bdgg0c0n28x14l2hd83rbx3c0000gn/T/ipykernel_5956/2305954420.py in <module>
#       9         output = model(X_tensor)
#      10         grads = tape.gradient(output, X_tensor)
# ---> 11     hessian1 = tape2.gradient(grads[:, f_to_i("log(S/K)")], X_tensor)
#      12
#      13 grads = grads.numpy()
#
# /var/folders/gg/bdgg0c0n28x14l2hd83rbx3c0000gn/T/ipykernel_5956/683383516.py in <lambda>(x)
#       6 X_df = pd.read_csv("datasets/sabr.csv")
#       7 feat_names = ['S/K','ttm',"V", "vol_of_vol","beta", "rho"]
# ----> 8 f_to_i = lambda x: feat_names.index(x)
#       9 Xs = X_df[feat_names].values
#      10 ys = X_df['call_payoff']
#
# ValueError: 'log(S/K)' is not in list

# %%
pd.concat(all_res).T.style.background_gradient(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gg/bdgg0c0n28x14l2hd83rbx3c0000gn/T/ipykernel_5956/317766389.py in <module>
# ----> 1 pd.concat(all_res).T.style.background_gradient(axis = 1)
#
# /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# /usr/local/lib/python3.9/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     349
#     350         if len(objs) == 0:
# --> 351             raise ValueError("No objects to concatenate")
#     352
#     353         if keys is None:
#
# ValueError: No objects to concatenate
